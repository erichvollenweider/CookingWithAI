# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import MultiLabelBinarizer
from PIL import Image, UnidentifiedImageError

# Ruta de la carpeta de imagenes y del CSV.
image_dir = '/content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2'
csv_file = '/content/drive/My Drive/Proyecto-DataSets/dataset-c.csv'

df = pd.read_csv(csv_file)

# Dado el dataset, si hay varios ingredientes que machee con una coma entre cada ingrediente
df['label'] = df['label'].apply(lambda x: x.split(','))

# Función para convertir imágenes de paleta (modo 'P') a RGBA
# Ya que se necesita tener las imagenes en RGBA
def convertir_a_rgba(image_path):
    try:
        # Verifica si la imagen es .png antes de intentar convertir
        if image_path.lower().endswith('.png'):
            with Image.open(image_path) as img:
                if img.mode == 'P':  # Solo convertir si está en modo Paleta (P)
                    img = img.convert('RGBA')
                    img.save(image_path)  # Sobreescribe la imagen en RGBA
                    print(f"Convertida: {image_path} a RGBA")
                else:
                    print(f"La imagen {image_path} ya está en modo {img.mode}")
        else:
            print(f"{image_path} no es un archivo PNG. No se requiere conversión.")
    except UnidentifiedImageError:
        print(f"Error al abrir la imagen {image_path}")
    except Exception as e:
        print(f"Ocurrió un error al procesar {image_path}: {e}")
        return False

valid_extensions = ['.jpg', '.jpeg', '.png']

# Listas para almacenar imágenes y etiquetas válidas
valid_images = []
valid_labels = []

# Recorre cada fila del DataFrame
for i, row in df.iterrows():
    image_path = os.path.join(image_dir, row['image'])

    # Verificar que la imagen exista, no esté vacía y tenga una extensión válida
    if os.path.exists(image_path) and os.path.getsize(image_path) > 0 and any(image_path.lower().endswith(ext) for ext in valid_extensions):

        # Convierte la imagen a RGBA si está en formato de paleta
        convertir_a_rgba(image_path)

        # Si la imagen es válida, se agrega a la lista
        valid_images.append(row['image'])
        valid_labels.append(row['label'])
    else:
        print(f"La imagen {row['image']} no existe o está vacía.")

print(f"Número total de imágenes en el CSV: {len(df)}")
print(f"Número de imágenes válidas: {len(valid_images)}")

# Crea un nuevo DataFrame solo con las imágenes y etiquetas válidas
df_valid = pd.DataFrame({
    'image': valid_images,
    'label': valid_labels
})

# Aplicar One-Hot Encoding a las etiquetas (es decir si en una imagen hay mas de un ingrediente, cada clase tiene un 1)
mlb = MultiLabelBinarizer()
df_valid['one_hot_label'] = mlb.fit_transform(df_valid['label']).tolist()

# Crear el dataset final con las imágenes y las etiquetas one-hot
one_hot_labels = pd.DataFrame(df_valid['one_hot_label'].to_list(), columns=mlb.classes_)
df_final = pd.concat([df_valid['image'], one_hot_labels], axis=1)

# Guardar el dataset limpio con one-hot encoding
clean_csv_path = '/content/drive/My Drive/Proyecto-DataSets/dataset-carnes.csv'
df_final.to_csv(clean_csv_path, index=False)

# Muestra las clases que se han codificado
print("Clases: ", mlb.classes_)
# Out:
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mor20.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/cost20.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/mil20.jpeg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo1.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo2.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo3.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo4.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo5.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo7.jpeg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo8.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pollo20.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pec20.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pm20.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/al20.jpeg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin1.png ya está en modo RGB
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin2.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin3.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin4.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin5.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin6.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin7.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin8.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin9.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin10.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin11.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin12.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin13.png ya está en modo RGB
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin14.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin15.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin16.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin17.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chinchulin20.jpeg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo1.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo2.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo3.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo4.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo5.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo6.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo7.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo9.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo10.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo11.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo12.png ya está en modo RGB
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo13.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo14.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo15.jpeg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo16.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo17.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/chorizo20.jpeg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon1.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon2.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon3.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon4.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon5.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon6.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon7.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon8.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon9.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon10.jpg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon11.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon12.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon13.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon14.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon15.png ya está en modo RGBA
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon16.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon18.jpg no es un archivo PNG. No se requiere conversión.
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon19.png ya está en modo RGB
# La imagen /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/riñon20.png ya está en modo RGBA
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/pan20.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha1.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha2.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha3.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha4.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha5.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha6.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha7.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha8.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha9.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha10.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha11.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha12.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha13.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha14.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha15.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha16.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha17.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha18.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha19.jpeg no es un archivo PNG. No se requiere conversión.
# /content/drive/My Drive/Proyecto-DataSets/imagenes-dataset-2/ha20.jpeg no es un archivo PNG. No se requiere conversión.
# Número total de imágenes en el CSV: 240
# Número de imágenes válidas: 240
# Clases:  ['alita' 'chinchulin' 'chorizo' 'costeleta de cerdo' 'hamburguesa'
#  'milanesa' 'morcilla' 'pan' 'pata-muslo' 'pechuga' 'pollo' 'riñon']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf

# Se normaliza de 0 a 1 para un entrenamiento mejor y luego se aplica 20% de validacion.
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)


# Dataset de entrenamiento
train_dataset = datagen.flow_from_dataframe(
    dataframe=df_final,
    directory=image_dir,
    x_col="image",
    y_col=mlb.classes_.tolist(), # Cada imagen esta asociada con las etiquetas correctas
    target_size=(224, 224), # Tamaño de la imagen, que luego espera MobileNet
    batch_size=32,  # Tamaño del batch que entrena
    class_mode="raw",
    subset="training", # Subconjunto para entrenamiento
    shuffle=True # Mezcla los datos en cada época para mejorar la generalizacion.
)

# Dataset de validación
validation_dataset = datagen.flow_from_dataframe(
    dataframe=df_final,
    directory=image_dir,
    x_col="image",
    y_col=mlb.classes_.tolist(),
    target_size=(224, 224),
    batch_size=32, # Tamaño del batch que valida, que luego espera MobileNet
    class_mode="raw",
    subset="validation"  # Subconjunto para validación
)
# Out:
# Found 192 validated image filenames.
# Found 48 validated image filenames.

# %%
import matplotlib.pyplot as plt

class_indices = {i: label for i, label in enumerate(mlb.classes_)}  # Crear diccionario de índices de clase , para ver las etiquetas con la imagen bien.

image, label = next(train_dataset)

plt.figure(figsize=(10, 10))
for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image[i])
    plt.title(', '.join([class_indices[j] for j in range(len(label[i])) if label[i][j] > 0]))
    plt.axis("off")
    plt.show()

# %%
import tensorflow as tf
from tensorflow.keras import regularizers

# Data augmentation para que no generalize o sobreajuste al entrenarse
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomTranslation(0.2, 0.2)
])

# Modelo preentrenado MobileNet
base_model = tf.keras.applications.MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# Congelamos las capas del modelo base para que solo MobileNet se use como extractor de caracteristicas y nada mas.
for layer in base_model.layers:
    layer.trainable = False


# Construcción del modelo
model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224, 224, 3)), # Capa de entrada que espera el MobileNet , 224 x 224 y RGB es decir 3.
    data_augmentation,  # Aumentación de datos
    base_model,  # Modelo base
    # En este paso se empiezan a entrenar el dataset nuestro, capas personalizadas para nuestro problema particular.
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(512, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(mlb.classes_), activation='sigmoid') # Capa de salida con depende cuantas clases se entrene.
])

# Compilamos el modelo con un optimizador Adam.
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),  # Bajamos la tasa de aprendizaje para un ajuste más fino.
    loss='binary_crossentropy', # Binary_crossentropy ya que es para problema multilabel como este.
    metrics=[tf.keras.metrics.CategoricalAccuracy(name='accuracy'),
             tf.keras.metrics.AUC(name='auc'),
             tf.keras.metrics.Precision(),
             tf.keras.metrics.Recall()
    ]
)

# Resumen del modelo para ver las capas, como entran y como salen.
model.summary()

# Callbacks

# EarlyStopping con monitoreo de 'val_loss' y paciencia ajustada
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=50,
    restore_best_weights=True
)

# ReduceLROnPlateau para ajustar la tasa de aprendizaje cuando la pérdida no mejora
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.2,
    patience=12,
    min_lr=0.00001
)

# Entrenamiento
history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=110,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 15s 507ms/step - accuracy: 0.0844 - auc: 0.5132 - loss: 13.2825 - precision_42: 0.0813 - recall_42: 0.4756 - val_accuracy: 0.0000e+00 - val_auc: 0.1976 - val_loss: 12.1040 - val_precision_42: 0.0045 - val_recall_42: 0.0208 - learning_rate: 0.0010
# Epoch 2/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 127ms/step - accuracy: 0.0934 - auc: 0.5831 - loss: 12.0364 - precision_42: 0.1028 - recall_42: 0.5026 - val_accuracy: 0.0000e+00 - val_auc: 0.1742 - val_loss: 11.1409 - val_precision_42: 0.0000e+00 - val_recall_42: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - accuracy: 0.1911 - auc: 0.6417 - loss: 10.9136 - precision_42: 0.1438 - recall_42: 0.4962 - val_accuracy: 0.0000e+00 - val_auc: 0.1673 - val_loss: 10.2164 - val_precision_42: 0.0000e+00 - val_recall_42: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 143ms/step - accuracy: 0.1945 - auc: 0.6543 - loss: 9.9935 - precision_42: 0.1321 - recall_42: 0.3923 - val_accuracy: 0.0000e+00 - val_auc: 0.1588 - val_loss: 9.3532 - val_precision_42: 0.0000e+00 - val_recall_42: 0.0000e+00 - learning_rate: 0.0010
# Epoch 5/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.2919 - auc: 0.7461 - loss: 9.0761 - precision_42: 0.2146 - recall_42: 0.5185 - val_accuracy: 0.0000e+00 - val_auc: 0.2159 - val_loss: 8.5474 - val_precision_42: 0.0000e+00 - val_recall_42: 0.0000e+00 - learning_rate: 0.0010
# Epoch 6/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 144ms/step - accuracy: 0.2429 - auc: 0.7172 - loss: 8.2970 - precision_42: 0.2008 - recall_42: 0.4178 - val_accuracy: 0.0000e+00 - val_auc: 0.2951 - val_loss: 7.8101 - val_precision_42: 0.0000e+00 - val_recall_42: 0.0000e+00 - learning_rate: 0.0010
# Epoch 7/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.3360 - auc: 0.7706 - loss: 7.5313 - precision_42: 0.2816 - recall_42: 0.4455 - val_accuracy: 0.0625 - val_auc: 0.3434 - val_loss: 7.1402 - val_precision_42: 0.0000e+00 - val_recall_42: 0.0000e+00 - learning_rate: 0.0010
# Epoch 8/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step
110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - accuracy: 0.9294 - auc: 0.9984 - loss: 0.1184 - precision_42: 0.9583 - recall_42: 0.9100 - val_accuracy: 0.1667 - val_auc: 0.4082 - val_loss: 0.4338 - val_precision_42: 0.3750 - val_recall_42: 0.1250 - learning_rate: 2.0000e-04
# Epoch 106/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.9827 - auc: 0.9992 - loss: 0.1075 - precision_42: 0.9852 - recall_42: 0.9446 - val_accuracy: 0.1667 - val_auc: 0.4341 - val_loss: 0.4275 - val_precision_42: 0.4375 - val_recall_42: 0.1458 - learning_rate: 2.0000e-04
# Epoch 107/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.9818 - auc: 0.9994 - loss: 0.1014 - precision_42: 0.9849 - recall_42: 0.9519 - val_accuracy: 0.1667 - val_auc: 0.4406 - val_loss: 0.4266 - val_precision_42: 0.4375 - val_recall_42: 0.1458 - learning_rate: 2.0000e-04
# Epoch 108/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 139ms/step - accuracy: 0.9834 - auc: 0.9983 - loss: 0.1011 - precision_42: 0.9817 - recall_42: 0.9658 - val_accuracy: 0.1667 - val_auc: 0.4412 - val_loss: 0.4275 - val_precision_42: 0.4375 - val_recall_42: 0.1458 - learning_rate: 2.0000e-04
# Epoch 109/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 133ms/step - accuracy: 0.9930 - auc: 0.9998 - loss: 0.1009 - precision_42: 0.9941 - recall_42: 0.9900 - val_accuracy: 0.1667 - val_auc: 0.4419 - val_loss: 0.4307 - val_precision_42: 0.3684 - val_recall_42: 0.1458 - learning_rate: 2.0000e-04
# Epoch 110/110
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - accuracy: 0.9854 - auc: 0.9997 - loss: 0.1019 - precision_42: 0.9784 - recall_42: 0.9606 - val_accuracy: 0.1667 - val_auc: 0.4271 - val_loss: 0.4333 - val_precision_42: 0.3333 - val_recall_42: 0.1458 - learning_rate: 2.0000e-04

# %%
loss, accuracy, auc, precision, recall = model.evaluate(train_dataset)
print(f"loss en entrenamiento: {loss}")
print(f"accuracy en entrenamiento: {accuracy}")
print(f"auc en entrenamiento: {auc}")
print(f"precision en entrenamiento: {precision}")
print(f"recall en entrenamiento: {recall}")
val_loss, val_accuracy, val_auc, val_precision, val_recall = model.evaluate(validation_dataset)
print(f"perdida en validación: {val_loss}")
print(f"accuracy en validación: {val_accuracy}")
print(f"auc en validación: {val_auc}")
print(f"precisión en validación: {val_precision}")
print(f"recall en validación: {val_recall}")
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - accuracy: 1.0000 - auc: 1.0000 - loss: 0.1068 - precision_42: 1.0000 - recall_42: 0.9563
# loss en entrenamiento: 0.10568740963935852
# accuracy en entrenamiento: 1.0
# auc en entrenamiento: 1.0
# precision en entrenamiento: 1.0
# recall en entrenamiento: 0.9635416865348816
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.1632 - auc: 0.4241 - loss: 0.4294 - precision_42: 0.4583 - recall_42: 0.1493
# perdida en validación: 0.4265504777431488
# accuracy en validación: 0.1666666716337204
# auc en validación: 0.44055792689323425
# precisión en validación: 0.4375
# recall en validación: 0.1458333283662796

# %%
# Graficar loss y val_loss
plt.figure(figsize=(12, 6))

# Pérdida del entrenamiento
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss durante el Entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('Pérdida')
plt.legend()

# AUC del entrenamiento
plt.subplot(1, 2, 2)
plt.plot(history.history['auc'], label='AUC')
plt.plot(history.history['val_auc'], label='Val AUC')
plt.title('AUC durante el Entrenamiento')
plt.xlabel('Épocas')
plt.ylabel('AUC')
plt.legend()

plt.show()

# %%
model_save_path = '/content/drive/My Drive/Proyecto-DataSets/modeloEntrenadov3.keras'
model.save(model_save_path)
